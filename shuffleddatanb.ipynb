# %%
# working with dataframes
import pandas as pd
import numpy as np

# working with paths for files
import pathlib, glob
from pathlib import Path

import os

# %%
path = Path("../1015finalproject/shuffleddata.csv")
df = pd.read_csv(path)

# %%
df
# Out:
#       Unnamed: 0  example_id resist  is_train micro_prev_organism
# 0          18751       90807   None         1      Escherichia 14
# 1          85314       82066   None         0   Staphylococcus 30
# 2          80763       64058   None         1     Enterobacter 30
# 3         116919       86632   None         0      Klebsiella 180
# 4          65887       89313   None         1   Staphylococcus 30
# ...          ...         ...    ...       ...                 ...
# 9995      108062       57261   None         1   Streptococcus 180
# 9996      137280      106618   None         1     Enterococcus 90
# 9997      120096       64514   None         1    Acinetobacter 90
# 9998       59744       23397   None         1          Proteus 30
# 9999       49341       64976    SXT         0       Klebsiella 30
#
# [10000 rows x 5 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

X_encoded = pd.get_dummies(df['micro_prev_organism'])
y_encoded = pd.get_dummies(df['resist'])

is_train = df['is_train'] == 1
X_train = X_encoded[is_train]
y_train = y_encoded[is_train]

X_test = X_encoded[~is_train]
y_test = y_encoded[~is_train]

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("y_pred length", len(y_pred))

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# y_pred length 2680
# Accuracy: 0.6951492537313433
